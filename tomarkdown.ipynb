# %%
import pdf4llm
from langchain.text_splitter import MarkdownTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain_community.llms import LlamaCpp
from langchain.chains import LLMChain
from langchain.chains.prompt_selector import ConditionalPromptSelector
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# %%
# get the md text
md_text = pdf4llm.to_markdown("nvidia.pdf")  

# check for the md text
# output_file = "testn.md"
# with open(output_file, "w", encoding="utf-8") as f:
#     f.write(md_text)

# print('output_file is saved')

# %%
# split the md into chunks
splitter = MarkdownTextSplitter(chunk_size=40, chunk_overlap=0)
splitter.create_documents([md_text])
# Out:
# [Document(page_content='# FORM 4'),
#  Document(page_content='OMB APPROVAL\nOMB Number: 3235-0287'),
#  Document(page_content='Estimated average burden'),
#  Document(page_content='hours per response... 0.5'),
#  Document(page_content='## UNITED STATES SECURITIES AND'),
#  Document(page_content='EXCHANGE COMMISSION'),
#  Document(page_content='## Washington, D.C. 20549'),
#  Document(page_content='## STATEMENT OF CHANGES IN BENEFICIAL'),
#  Document(page_content='OWNERSHIP OF'),
#  Document(page_content='## SECURITIES\n\n##'),
#  Document(page_content='## ☐ Check this box if no longer'),
#  Document(page_content='subject to Section 16. Form 4 or'),
#  Document(page_content='Form 5 obligations may'),
#  Document(page_content='continue. _See_ Instruction 1(b).'),
#  Document(page_content='## ☐ Check this box to indicate'),
#  Document(page_content='that a transaction was made'),
#  Document(page_content='pursuant to a contract,'),
#  Document(page_content='instruction or written plan that is'),
#  Document(page_content='intended to satisfy the'),
#  Document(page_content='affirmative defense conditions'),
#  Document(page_content='of Rule 10b5-1(c). See\nInstruction 10.'),
#  Document(page_content='##'),
#  Document(page_content='## Filed pursuant to Section 16(a) of'),
#  Document(page_content='the Securities Exchange Act of 1934 or'),
#  Document(page_content='## Section 30(h) of the Investment'),
#  Document(page_content='Company Act of 1940'),
#  Document(page_content='##'),
#  Document(page_content='|1. Name and Address of Reporting'),
#  Document(page_content='Person * Drell'),
#  Document(page_content='Persis|Col2|Col3|Col4|Col5|Col6|2.'),
#  Document(page_content='Issuer Name and Ticker or Trading'),
#  Document(page_content='Symbol NVIDIA CORP [ NVDA'),
#  Document(page_content=']|Col8|Col9|Col10|Col11|Col12|Col13|Col'),
#  Document(page_content='14|Col15|Col16|Col17|Col18|Col19|5.'),
#  Document(page_content='Relationship of Reporting Person(s) to'),
#  Document(page_content='Issuer (Check all applicable) __X__'),
#  Document(page_content='Director _____ 10% Owner _____ Officer'),
#  Document(page_content='(give title below) _____ Other (specify'),
#  Document(page_content='below)|Col21|Col22|Col23|Col24|'),
#  Document(page_content='|---|---|---|---|---|---|---|---|---|--'),
#  Document(page_content='-|---|---|---|---|---|---|---|---|---|--'),
#  Document(page_content='-|---|---|---|---|'),
#  Document(page_content='|(Last) (First) (Middle) C/O NVIDIA'),
#  Document(page_content='CORPORATION, 2788 SAN TOMAS'),
#  Document(page_content='EXPRESSWAY||||||3. Date of Earliest'),
#  Document(page_content='Transaction (MM/DD/YYYY)'),
#  Document(page_content='10/6/2023||||||||||||||||||'),
#  Document(page_content='|(Street) SANTA CLARA, CA 95051||||||4.'),
#  Document(page_content='If Amendment, Date Original Filed'),
#  Document(page_content='(MM/DD/YYYY)|||||||||||||6. Individual'),
#  Document(page_content='or Joint/Group Filing (Check Applicable'),
#  Document(page_content='Line) _X _ Form filed by One Reporting'),
#  Document(page_content='Person ___ Form filed by More than One'),
#  Document(page_content='Reporting Person|||||'),
#  Document(page_content='|(City) (State)'),
#  Document(page_content='(Zip)||||||||||||||||||||||||'),
#  Document(page_content='|Table I - Non-Derivative Securities'),
#  Document(page_content='Acquired, Disposed of, or Beneficially'),
#  Document(page_content='Owned||||||||||||||||||||||||'),
#  Document(page_content='|1.Title of Security (Instr. 3)||||2.'),
#  Document(page_content='Trans. Date|||2A. Deemed Execution'),
#  Document(page_content='Date, if any||3. Trans. Code (Instr.'),
#  Document(page_content='8)|||4. Securities Acquired (A) or'),
#  Document(page_content='Disposed of (D) (Instr. 3, 4 and'),
#  Document(page_content='5)||||||5. Amount of Securities'),
#  Document(page_content='Beneficially Owned Following Reported'),
#  Document(page_content='Transaction(s) (Instr. 3 and 4)||||6.'),
#  Document(page_content='Ownership Form: Direct (D) or Indirect'),
#  Document(page_content='(I) (Instr. 4)|7. Nature of Indirect'),
#  Document(page_content='Beneficial Ownership (Instr. 4)|'),
#  Document(page_content='||||||||||Code||V|Amount||(A) or'),
#  Document(page_content='(D)||Price||||||||'),
#  Document(page_content='|Common'),
#  Document(page_content='Stock||||10/6/2023|||||G|||2,300||D||$0'),
#  Document(page_content='(1)||7,106||||I|The Welch- Drell 2009'),
#  Document(page_content='Revocable Trust (2)|'),
#  Document(page_content='|Common'),
#  Document(page_content='Stock||||||||||||||||||26,518||||D||'),
#  Document(page_content='|Common'),
#  Document(page_content='Stock||||||||||||||||||68||||I|Rose I'),
#  Document(page_content='Welch|'),
#  Document(page_content='|Common'),
#  Document(page_content='Stock||||||||||||||||||68||||I|Joseph'),
#  Document(page_content='Welch|'),
#  Document(page_content='|Common'),
#  Document(page_content='Stock||||||||||||||||||68||||I|Cornelia'),
#  Document(page_content='I Welch|'),
#  Document(page_content='|Table II - Derivative Securities'),
#  Document(page_content='Beneficially Owned (e.g., puts, calls,'),
#  Document(page_content='warrants, options, convertible'),
#  Document(page_content='securities)||||||||||||||||||||||||'),
#  Document(page_content='|1. Title of Derivate Security (Instr.'),
#  Document(page_content='3)|2. Conversion or Exercise Price of'),
#  Document(page_content='Derivative Security|3. Trans. Date|3A.'),
#  Document(page_content='Deemed Execution Date, if any||4.'),
#  Document(page_content='Trans. Code (Instr. 8)|||5. Number of'),
#  Document(page_content='Derivative Securities Acquired (A) or'),
#  Document(page_content='Disposed of (D) (Instr. 3, 4 and'),
#  Document(page_content='5)|||6. Date Exercisable and Expiration'),
#  Document(page_content='Date||||7. Title and Amount of'),
#  Document(page_content='Securities Underlying Derivative'),
#  Document(page_content='Security (Instr. 3 and 4)|||||8. Price'),
#  Document(page_content='of Derivative Security (Instr. 5)|9.'),
#  Document(page_content='Number of derivative Securities'),
#  Document(page_content='Beneficially Owned Following Reported'),
#  Document(page_content='Transaction(s) (Instr. 4)|10. Ownership'),
#  Document(page_content='Form of Derivative Security: Direct (D)'),
#  Document(page_content='or Indirect (I) (Instr. 4)|11. Nature'),
#  Document(page_content='of Indirect Beneficial Ownership'),
#  Document(page_content='(Instr. 4)|'),
#  Document(page_content='||||||Code||V|(A)||(D)|Date'),
#  Document(page_content='Exercisable||Expiration'),
#  Document(page_content='Date||Title||Amount or Number of'),
#  Document(page_content='Shares|||||||'),
#  Document(page_content='**Explanation of Responses:**'),
#  Document(page_content='**(1)** Gift without consideration.'),
#  Document(page_content='**(2)** The shares are held by the'),
#  Document(page_content='Welch-Drell 2009 Revocable Trust, U/A'),
#  Document(page_content='DTD April 16, 2009 (the "Trust"), of'),
#  Document(page_content='which the Reporting Person is a'),
#  Document(page_content='trustee.'),
#  Document(page_content='|Reporting Owners|Col2|Col3|Col4|Col5|'),
#  Document(page_content='|---|---|---|---|---|'),
#  Document(page_content='|Reporting Owner Name /'),
#  Document(page_content='Address|Relationships||||'),
#  Document(page_content='||Director|10% Owne|rOfficer|Other|'),
#  Document(page_content='|Drell Persis C/O NVIDIA CORPORATION'),
#  Document(page_content='2788 SAN TOMAS EXPRESSWAY SANTA CLARA,'),
#  Document(page_content='CA 95051|X||||'),
#  Document(page_content='-----\n\n\n**Signatures**'),
#  Document(page_content='**/s/ Rebecca Peters, Attorney-in-Fact'),
#  Document(page_content='for Persis S. Drell** **10/9/2023**'),
#  Document(page_content='** Signature of Reporting Person Date'),
#  Document(page_content='Reminder: Report on a separate line for'),
#  Document(page_content='each class of securities beneficially'),
#  Document(page_content='owned directly or indirectly.'),
#  Document(page_content='***** If the form is filed by more than'),
#  Document(page_content='one reporting person, _see_ Instruction'),
#  Document(page_content='4(b)(v).'),
#  Document(page_content='****** Intentional misstatements or'),
#  Document(page_content='omissions of facts constitute Federal'),
#  Document(page_content='Criminal Violations. _See_ 18 U.S.C.'),
#  Document(page_content='1001 and 15 U.S.C. 78ff(a).'),
#  Document(page_content='Note: File three copies of this Form,'),
#  Document(page_content='one of which must be manually signed.'),
#  Document(page_content='If space is insufficient, _see_'),
#  Document(page_content='Instruction 6 for procedure.'),
#  Document(page_content='Persons who respond to the collection'),
#  Document(page_content='of information contained in this form'),
#  Document(page_content='are not required to respond unless the'),
#  Document(page_content='form displays a currently valid OMB'),
#  Document(page_content='control'),
#  Document(page_content='number.'),
#  Document(page_content='-----')]

# %%
# load embbeding model
# supplying a persist_directory will store the embeddings on disk
from langchain_community.embeddings import GPT4AllEmbeddings
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.from_documents(documents=splitter, embedding=GPT4AllEmbeddings())
# Out:
# Downloading: 100%|██████████| 45.9M/45.9M [00:02<00:00, 16.7MiB/s]
# Verifying: 100%|██████████| 45.9M/45.9M [00:00<00:00, 286MiB/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 6
#       3 from langchain_community.embeddings import GPT4AllEmbeddings
#       4 from langchain_community.vectorstores import Chroma
# ----> 6 vectorstore = Chroma.from_documents(documents=splitter, embedding=GPT4AllEmbeddings())
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/pydantic/v1/main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/pydantic/v1/main.py:1100, in validate_model(model, input_data, cls)
#    1098     continue
#    1099 try:
# -> 1100     values = validator(cls_, values)
#    1101 except (ValueError, TypeError, AssertionError) as exc:
#    1102     errors.append(ErrorWrapper(exc, loc=ROOT_KEY))
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/langchain_community/embeddings/gpt4all.py:29, in GPT4AllEmbeddings.validate_environment(cls, values)
#      26 try:
#      27     from gpt4all import Embed4All
# ---> 29     values["client"] = Embed4All()
#      30 except ImportError:
#      31     raise ImportError(
#      32         "Could not import gpt4all library. "
#      33         "Please install the gpt4all library to "
#      34         "use this embedding model: pip install gpt4all"
#      35     )
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/gpt4all/gpt4all.py:58, in Embed4All.__init__(self, model_name, n_threads, device, **kwargs)
#      56 if model_name is None:
#      57     model_name = 'all-MiniLM-L6-v2.gguf2.f16.gguf'
# ---> 58 self.gpt4all = GPT4All(model_name, n_threads=n_threads, device=device, **kwargs)
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/gpt4all/gpt4all.py:206, in GPT4All.__init__(self, model_name, model_path, model_type, allow_download, n_threads, device, n_ctx, ngl, verbose)
#     204 # Retrieve model and download if allowed
#     205 self.config: ConfigType = self.retrieve_model(model_name, model_path=model_path, allow_download=allow_download, verbose=verbose)
# --> 206 self.model = LLModel(self.config["path"], n_ctx, ngl)
#     207 if device is not None and device != "cpu":
#     208     self.model.init_gpu(device)
#
# File ~/opt/anaconda3/envs/rag/lib/python3.10/site-packages/gpt4all/_pyllmodel.py:218, in LLModel.__init__(self, model_path, n_ctx, ngl)
#     216 if model is None:
#     217     s = err.value
# --> 218     raise RuntimeError(f"Unable to instantiate model: {'null' if s is None else s.decode()}")
#     219 self.model: ctypes.c_void_p | None = model
#
# RuntimeError: Unable to instantiate model: CPU does not support AVX
